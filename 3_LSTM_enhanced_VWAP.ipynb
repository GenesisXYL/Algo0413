# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation, Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import keras
import pickle
import os
from keras.layers import Dense, Conv2D, Flatten, Dropout
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
from models import *

# %%
from gen_train_test_data import *
from simtools import *
# %load_ext autoreload
# %autoreload 2

# load scaler        
with open("model/scaler_{}_{}.p".format(train_date_list[0],train_date_list[-1]),"rb") as f:
        scaler=pickle.load(f)

# %%
date_pool=pd.date_range("1/1/2019","1/31/2019",freq="B").strftime("%Y%m%d")
date_pool=[d for d in date_pool if os.path.exists(data_dir+"trades_{}_{}.csv".format(d,ticker))]

train_days=10
train_date_list=date_pool[:train_days]
test_date_list=date_pool[train_days+1:]

# %%
## Global Constants

# %%
ticker="TSLA"

time_steps = 50

# %% [markdown]
# ## Load Models

# %%
import os
import re

model_list = os.listdir("model/")
model_list = [s for s in model_list if ((re.search(r'scaler', s) is None) and (re.search(r'[a-zA-Z0-9]*\.p', s)))]

print(model_list)
# Out:
# ['Random_Forest_20190102_20190115.p', 'GradientBoost_20190102_20190115.p', 'RandomForest_20190102_20190115.p', 'XGBoost_20190102_20190115.p', 'LSTM_20190102_20190115.p', 'CNN_20190102_20190115.p']

# %% [markdown]
# ## Model Prediction

# %%
import vwap2 as vw
matplotlib.rcParams[ 'figure.figsize' ] = ( 16, 9 )
vwap_coefs = [ 9.95503275e-03, -1.01533564e-04,  5.73879785e-07, -1.47027197e-09, 1.38993793e-12]
#test_date_list_new=list(test_taq.keys())
#day = test_taq[test_date_list_new[0]]
#day[~day.trade_px.isna()]

# %%
def test_vwap(day, order_quantity, order_side, schedule_coef = -1.0, tick_coef = 0., model_coef = 1.,model=True):
    results = vw.algo_loop(day, order_side, order_quantity, vwap_coefs, schedule_coef = schedule_coef,\
                           tick_coef = tick_coef, model_coef = model_coef, using_model=model)
    display_result(results,False)
    return results

def display_result(results,plot=True):
    data = results['trades']
    if plot:
        print("FV and midpoints:")
        plt.plot(results['fair_values'].index,results['fair_values'].values,color='r')
        plt.plot(results['midpoints'].index,results['midpoints'].values,color='r')
        plt.legend(["fair_values","midpoints"])
        plt.show()
        print("Trade prices:")
        plt.plot(data.price.index,data.price.values,color=taolaoshi[0])
        plt.show()
    print("percentage of aggressive order:",np.mean(data['trade_type']=="a"))
    print("last_min_order:",results['last_min_order'])
    print("avg price:",results['avg_price'])
    print("day_vwap price:",results['day_vwap'])
    print("avg - day_vwap:",results['avg_price'] - results['day_vwap'])

# %%
def model_vwap_evaluation(model, order_side):
    for date in test_date_list:
        if not os.path.exists("test_result/x_test_{}.p".format(date)):
            x,idx=create_test_dataset(ticker=ticker,time_steps = time_steps, input_scaler=scaler, date=date)
            print(x.shape,idx.shape)
            with open("test_result/x_test_{}.p".format(date),"wb") as f:
                    pickle.dump(x,f)
        
        x = None
        with open("test_result/x_test_{}.p".format(date),"rb") as f:
            x = pickle.load(f)

        # Using Model for Prediction
        signal=model.predict(x)
        with open("test_result/signal_test_{}.p".format(date),"wb") as f:
                pickle.dump(signal,f)
        
        log_message( "{} finished".format(date) )

    test_taq=dict()

    for date in test_date_list:
        if os.path.exists("test_result/x_test_{}.p".format(date)) and os.path.exists(data_dir+"quotes_{}_TSLA.csv".format(date)):

            with open("test_result/signal_test_{}.p".format(date),"rb") as f:
                signal=pickle.load(f)
            #print(signal[-100:])

            # generate signal and attach it to original df
            if len(signal.shape) > 1:
                signal_discrete=signal.argmax(axis=1)-1
            else:
                signal_discrete=signal
            #signal_continuous=np.dot(signal,np.array([[-1],[0],[1]])).ravel()

            trades = pd.read_csv(data_dir+'trades_{}_{}.csv'.format(date, ticker),index_col=[0],parse_dates=[0])
            N=len(trades)

            signal_discrete=np.concatenate((np.zeros(N-len(signal_discrete))+np.nan,signal_discrete), axis=0)
            trades[["signal_discrete"]]=pd.DataFrame({"signal_discrete":signal_discrete,},index=trades.index)

            # merge TAQ
            quotes=pd.read_csv(data_dir+"quotes_{}_TSLA.csv".format(date),index_col=[0],parse_dates=[0])
            taq=makeTAQfile(trades, quotes)
            test_taq[date]=taq

            log_message( "{} finished".format(date) )
    i=0

    vwap_list=[]
    #avg_list_tick=[]
    avg_list_model=[]
    avg_spread=[]

    model_coef=0.1

    for date in test_taq.keys():
        print("-------------------------------------------------------------------------------------------------")
        day=test_taq[date]
        #print("----------------Tick-----------------")
        #r_tick=test_vwap(day, order_quantity=300000, order_side="s", schedule_coef = -1.0, tick_coef = 1., LSTM_coef = 0.,LSTM=False)
        print("----------------{}-----------------".format(model.model_name))
        r_model=test_vwap(day, order_quantity=300000, order_side="s", schedule_coef = -1.0, tick_coef = 0., model_coef = model_coef, model=True)

        vwap_list.append(r_model['day_vwap'])
        #avg_list_tick.append(r_tick['avg_price'])
        avg_list_model.append(r_model['avg_price'])
        avg_spread.append(r_model["avg_spread"])

        log_message( "{} finished".format(date) )
    
    return (vwap_list, avg_list_model, avg_spread, test_taq)

# %% [markdown]
# # Running of each model

# %% [markdown]
# ## CNN

# %%
with open("model/CNN_{}_{}.p".format(train_date_list[0],train_date_list[-1]),"rb") as f:
        model=pickle.load(f)
        print(model.model_name)
# Out:
# CNN

# %%
vwap_list, avg_list_CNN, avg_spread_CNN, test_taq = model_vwap_evaluation(model, 's')
# Out:
# 40414
# (40365, 50, 4) (40365,)
# 2020-04-23 16:05:32:288941: 20190117 finished
# 2020-04-23 16:05:59:819612: 20190118 finished
# 2020-04-23 16:06:14:384930: 20190122 finished
# 2020-04-23 16:06:30:796158: 20190123 finished
# 2020-04-23 16:06:40:601420: 20190124 finished
# 2020-04-23 16:06:49:997620: 20190125 finished
# 2020-04-23 16:06:58:524186: 20190128 finished
# 2020-04-23 16:07:04:471610: 20190129 finished
# 2020-04-23 16:07:16:103644: 20190130 finished
# 2020-04-23 16:07:34:406520: 20190131 finished
# 2020-04-23 16:07:34:518645: start merge
# 2020-04-23 16:07:34:545789: end merge
# 2020-04-23 16:07:34:545901: 20190117 finished
# 2020-04-23 16:07:35:125538: start merge
# 2020-04-23 16:07:35:297440: end merge
# 2020-04-23 16:07:35:297559: 20190118 finished
# 2020-04-23 16:07:35:487298: start merge
# 2020-04-23 16:07:35:539196: end merge
# 2020-04-23 16:07:35:539303: 20190124 finished
# 2020-04-23 16:07:35:707558: start merge
# 2020-04-23 16:07:35:752512: end merge
# 2020-04-23 16:07:35:752667: 20190125 finished
# 2020-04-23 16:07:35:898139: start merge
# 2020-04-23 16:07:35:938949: end merge
# 2020-04-23 16:07:35:939065: 20190128 finished
# 2020-04-23 16:07:36:059584: start merge
# 2020-04-23 16:07:36:091802: end merge
# 2020-04-23 16:07:36:091965: 20190129 finished
# 2020-04-23 16:07:36:348959: start merge
# 2020-04-23 16:07:36:422466: end merge
# 2020-04-23 16:07:36:422581: 20190130 finished
# 2020-04-23 16:07:36:681055: start merge
# 2020-04-23 16:07:36:750345: end merge
# 2020-04-23 16:07:36:750453: 20190131 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:07:36:750526: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1776
# 2020-04-23 16:07:36:756516: starting main loop
# 2020-04-23 16:07:59:685684: end simulation loop
# 2020-04-23 16:07:59:685774: order analytics
# 2020-04-23 16:07:59:688033: VWAP run complete.
# percentage of aggressive order: 0.06167400881057269
# last_min_order: 76560.0
# avg price: 347.30831363333334
# day_vwap price: 347.7609699903627
# avg - day_vwap: -0.4526563570293547
# 2020-04-23 16:07:59:692530: 20190117 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:07:59:692633: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0542
# 2020-04-23 16:07:59:703781: starting main loop
# 2020-04-23 16:10:16:018690: end simulation loop
# 2020-04-23 16:10:16:018791: order analytics
# 2020-04-23 16:10:16:021538: VWAP run complete.
# percentage of aggressive order: 0.030381622823267878
# last_min_order: 99153.0
# avg price: 308.9229896333333
# day_vwap price: 310.79745669649475
# avg - day_vwap: -1.8744670631614326
# 2020-04-23 16:10:16:054771: 20190118 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:10:16:054846: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1385
# 2020-04-23 16:10:16:060627: starting main loop
# 2020-04-23 16:11:04:638612: end simulation loop
# 2020-04-23 16:11:04:638728: order analytics
# 2020-04-23 16:11:04:641328: VWAP run complete.
# percentage of aggressive order: 0.029636711281070746
# last_min_order: 110045.0
# avg price: 289.1794005666667
# day_vwap price: 287.75255930110154
# avg - day_vwap: 1.4268412655651446
# 2020-04-23 16:11:04:651680: 20190124 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:11:04:651759: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1345
# 2020-04-23 16:11:04:657511: starting main loop
# 2020-04-23 16:11:44:786484: end simulation loop
# 2020-04-23 16:11:44:786582: order analytics
# 2020-04-23 16:11:44:789247: VWAP run complete.
# percentage of aggressive order: 0.015610651974288337
# last_min_order: 121667.0
# avg price: 295.46545506666666
# day_vwap price: 294.2529570043719
# avg - day_vwap: 1.2124980622947419
# 2020-04-23 16:11:44:800430: 20190125 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:11:44:800523: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1460
# 2020-04-23 16:11:44:808100: starting main loop
# 2020-04-23 16:12:19:187859: end simulation loop
# 2020-04-23 16:12:19:187950: order analytics
# 2020-04-23 16:12:19:190295: VWAP run complete.
# percentage of aggressive order: 0.03419746276889134
# last_min_order: 107526.0
# avg price: 294.37600986666666
# day_vwap price: 293.3454132785871
# avg - day_vwap: 1.0305965880795611
# 2020-04-23 16:12:19:198251: 20190128 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:12:19:198318: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1450
# 2020-04-23 16:12:19:202789: starting main loop
# 2020-04-23 16:12:48:216948: end simulation loop
# 2020-04-23 16:12:48:217041: order analytics
# 2020-04-23 16:12:48:219429: VWAP run complete.
# percentage of aggressive order: 0.03471826977803073
# last_min_order: 102405.0
# avg price: 296.12756379999996
# day_vwap price: 295.61633583089167
# avg - day_vwap: 0.5112279691082904
# 2020-04-23 16:12:48:224882: 20190129 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:12:48:224947: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0946
# 2020-04-23 16:12:48:232826: starting main loop
# 2020-04-23 16:14:00:371700: end simulation loop
# 2020-04-23 16:14:00:371794: order analytics
# 2020-04-23 16:14:00:374313: VWAP run complete.
# percentage of aggressive order: 0.017703862660944206
# last_min_order: 143737.0
# avg price: 305.6108270666667
# day_vwap price: 303.60644835608593
# avg - day_vwap: 2.0043787105807382
# 2020-04-23 16:14:00:392565: 20190130 finished
# -------------------------------------------------------------------------------------------------
# ----------------CNN-----------------
# 2020-04-23 16:14:00:392633: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1613
# 2020-04-23 16:14:00:400561: starting main loop
# 2020-04-23 16:14:58:530546: end simulation loop
# 2020-04-23 16:14:58:530641: order analytics
# 2020-04-23 16:14:58:532979: VWAP run complete.
# percentage of aggressive order: 0.0407911001236094
# last_min_order: 116438.0
# avg price: 305.7007889666667
# day_vwap price: 304.9707644846737
# avg - day_vwap: 0.7300244819930413
# 2020-04-23 16:14:58:549358: 20190131 finished

# %% [markdown]
# ## LSTM

# %%
with open("model/LSTM_{}_{}.p".format(train_date_list[0],train_date_list[-1]),"rb") as f:
        model=pickle.load(f)
        print(model.model_name)
vwap_list, avg_list_LSTM, avg_spread_LSTM, _ = model_vwap_evaluation(model, 's')
# Out:
# LSTM
# 2020-04-23 16:16:32:253828: 20190117 finished
# 2020-04-23 16:24:42:073689: 20190118 finished
# 2020-04-23 16:28:42:418072: 20190122 finished
# 2020-04-23 16:33:02:539922: 20190123 finished
# 2020-04-23 16:36:00:946807: 20190124 finished
# 2020-04-23 16:38:28:512439: 20190125 finished
# 2020-04-23 16:40:41:174812: 20190128 finished
# 2020-04-23 16:42:09:744820: 20190129 finished
# 2020-04-23 16:45:11:798727: 20190130 finished
# 2020-04-23 16:49:05:888193: 20190131 finished
# 2020-04-23 16:49:06:077097: start merge
# 2020-04-23 16:49:06:111705: end merge
# 2020-04-23 16:49:06:112280: 20190117 finished
# 2020-04-23 16:49:06:775891: start merge
# 2020-04-23 16:49:06:980423: end merge
# 2020-04-23 16:49:06:981073: 20190118 finished
# 2020-04-23 16:49:07:225004: start merge
# 2020-04-23 16:49:07:286605: end merge
# 2020-04-23 16:49:07:286738: 20190124 finished
# 2020-04-23 16:49:07:489328: start merge
# 2020-04-23 16:49:07:546175: end merge
# 2020-04-23 16:49:07:546299: 20190125 finished
# 2020-04-23 16:49:07:733344: start merge
# 2020-04-23 16:49:07:782628: end merge
# 2020-04-23 16:49:07:782768: 20190128 finished
# 2020-04-23 16:49:07:930417: start merge
# 2020-04-23 16:49:07:968209: end merge
# 2020-04-23 16:49:07:968363: 20190129 finished
# 2020-04-23 16:49:08:281392: start merge
# 2020-04-23 16:49:08:364496: end merge
# 2020-04-23 16:49:08:364631: 20190130 finished
# 2020-04-23 16:49:08:664666: start merge
# 2020-04-23 16:49:08:744644: end merge
# 2020-04-23 16:49:08:744767: 20190131 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:49:08:744841: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1776
# 2020-04-23 16:49:08:751437: starting main loop
# 2020-04-23 16:49:32:080565: end simulation loop
# 2020-04-23 16:49:32:080689: order analytics
# 2020-04-23 16:49:32:083583: VWAP run complete.
# percentage of aggressive order: 0.05979827089337176
# last_min_order: 76459.0
# avg price: 347.3054727333333
# day_vwap price: 347.7609699903627
# avg - day_vwap: -0.4554972570293785
# 2020-04-23 16:49:32:088421: 20190117 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:49:32:088486: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0542
# 2020-04-23 16:49:32:099892: starting main loop
# 2020-04-23 16:51:55:257439: end simulation loop
# 2020-04-23 16:51:55:257541: order analytics
# 2020-04-23 16:51:55:260267: VWAP run complete.
# percentage of aggressive order: 0.030381622823267878
# last_min_order: 98449.0
# avg price: 308.9361398666667
# day_vwap price: 310.79745669649475
# avg - day_vwap: -1.8613168298280698
# 2020-04-23 16:51:55:295929: 20190118 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:51:55:296011: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1385
# 2020-04-23 16:51:55:302036: starting main loop
# 2020-04-23 16:52:37:970518: end simulation loop
# 2020-04-23 16:52:37:970610: order analytics
# 2020-04-23 16:52:37:973201: VWAP run complete.
# percentage of aggressive order: 0.02967927237912877
# last_min_order: 110306.0
# avg price: 289.1831188333333
# day_vwap price: 287.75255930110154
# avg - day_vwap: 1.4305595322317686
# 2020-04-23 16:52:37:986446: 20190124 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:52:37:986534: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1345
# 2020-04-23 16:52:37:993058: starting main loop
# 2020-04-23 16:53:18:275118: end simulation loop
# 2020-04-23 16:53:18:275211: order analytics
# 2020-04-23 16:53:18:277671: VWAP run complete.
# percentage of aggressive order: 0.01608455882352941
# last_min_order: 121667.0
# avg price: 295.4658084
# day_vwap price: 294.2529570043719
# avg - day_vwap: 1.2128513956280926
# 2020-04-23 16:53:18:286434: 20190125 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:53:18:286501: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1460
# 2020-04-23 16:53:18:291430: starting main loop
# 2020-04-23 16:53:54:381587: end simulation loop
# 2020-04-23 16:53:54:381681: order analytics
# 2020-04-23 16:53:54:384337: VWAP run complete.
# percentage of aggressive order: 0.0365990990990991
# last_min_order: 107561.0
# avg price: 294.35305736666663
# day_vwap price: 293.3454132785871
# avg - day_vwap: 1.0076440880795303
# 2020-04-23 16:53:54:392859: 20190128 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:53:54:392934: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1450
# 2020-04-23 16:53:54:397937: starting main loop
# 2020-04-23 16:54:22:367167: end simulation loop
# 2020-04-23 16:54:22:367257: order analytics
# 2020-04-23 16:54:22:369704: VWAP run complete.
# percentage of aggressive order: 0.034071550255536626
# last_min_order: 103921.0
# avg price: 296.1372068666667
# day_vwap price: 295.61633583089167
# avg - day_vwap: 0.5208710357750306
# 2020-04-23 16:54:22:375599: 20190129 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:54:22:375662: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0946
# 2020-04-23 16:54:22:383185: starting main loop
# 2020-04-23 16:55:32:678111: end simulation loop
# 2020-04-23 16:55:32:678321: order analytics
# 2020-04-23 16:55:32:680842: VWAP run complete.
# percentage of aggressive order: 0.017780172413793104
# last_min_order: 142871.0
# avg price: 305.59422433333333
# day_vwap price: 303.60644835608593
# avg - day_vwap: 1.987775977247395
# 2020-04-23 16:55:32:699861: 20190130 finished
# -------------------------------------------------------------------------------------------------
# ----------------LSTM-----------------
# 2020-04-23 16:55:32:699930: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1613
# 2020-04-23 16:55:32:707565: starting main loop
# 2020-04-23 16:56:34:593775: end simulation loop
# 2020-04-23 16:56:34:593893: order analytics
# 2020-04-23 16:56:34:596754: VWAP run complete.
# percentage of aggressive order: 0.04176904176904177
# last_min_order: 114972.0
# avg price: 305.6991085
# day_vwap price: 304.9707644846737
# avg - day_vwap: 0.7283440153263427
# 2020-04-23 16:56:34:615356: 20190131 finished

# %% [markdown]
# ## Random Forest

# %%
with open("model/Random_Forest_{}_{}.p".format(train_date_list[0],train_date_list[-1]),"rb") as f:
        model=pickle.load(f)
vwap_list, avg_list_RF, avg_spread_RF, _ = model_vwap_evaluation(model, 's')
# Out:
# 2020-04-23 17:15:03:803290: 20190117 finished
# 2020-04-23 17:15:12:385912: 20190118 finished
# 2020-04-23 17:15:17:850312: 20190122 finished
# 2020-04-23 17:15:21:529605: 20190123 finished
# 2020-04-23 17:15:23:756417: 20190124 finished
# 2020-04-23 17:15:25:783259: 20190125 finished
# 2020-04-23 17:15:27:485929: 20190128 finished
# 2020-04-23 17:15:28:724981: 20190129 finished
# 2020-04-23 17:15:31:960020: 20190130 finished
# 2020-04-23 17:15:36:063764: 20190131 finished
# 2020-04-23 17:15:36:156994: start merge
# 2020-04-23 17:15:36:178777: end merge
# 2020-04-23 17:15:36:178865: 20190117 finished
# 2020-04-23 17:15:36:686644: start merge
# 2020-04-23 17:15:36:853950: end merge
# 2020-04-23 17:15:36:854087: 20190118 finished
# 2020-04-23 17:15:37:065518: start merge
# 2020-04-23 17:15:37:119060: end merge
# 2020-04-23 17:15:37:119169: 20190124 finished
# 2020-04-23 17:15:37:261570: start merge
# 2020-04-23 17:15:37:299678: end merge
# 2020-04-23 17:15:37:299775: 20190125 finished
# 2020-04-23 17:15:37:421572: start merge
# 2020-04-23 17:15:37:456548: end merge
# 2020-04-23 17:15:37:456650: 20190128 finished
# 2020-04-23 17:15:37:561058: start merge
# 2020-04-23 17:15:37:588690: end merge
# 2020-04-23 17:15:37:588784: 20190129 finished
# 2020-04-23 17:15:37:816627: start merge
# 2020-04-23 17:15:37:879808: end merge
# 2020-04-23 17:15:37:879927: 20190130 finished
# 2020-04-23 17:15:38:101358: start merge
# 2020-04-23 17:15:38:161780: end merge
# 2020-04-23 17:15:38:161873: 20190131 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:15:38:161929: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1776
# 2020-04-23 17:15:38:167540: starting main loop
# 2020-04-23 17:15:59:753414: end simulation loop
# 2020-04-23 17:15:59:753501: order analytics
# 2020-04-23 17:15:59:755878: VWAP run complete.
# percentage of aggressive order: 0.06040756914119359
# last_min_order: 76334.0
# avg price: 347.30534670000003
# day_vwap price: 347.7609699903627
# avg - day_vwap: -0.45562329036266647
# 2020-04-23 17:15:59:759715: 20190117 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:15:59:759776: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0542
# 2020-04-23 17:15:59:771328: starting main loop
# 2020-04-23 17:18:22:992468: end simulation loop
# 2020-04-23 17:18:22:992563: order analytics
# 2020-04-23 17:18:22:995332: VWAP run complete.
# percentage of aggressive order: 0.03166915052160954
# last_min_order: 97275.0
# avg price: 308.95258633333333
# day_vwap price: 310.79745669649475
# avg - day_vwap: -1.8448703631614194
# 2020-04-23 17:18:23:032320: 20190118 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:18:23:032391: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1385
# 2020-04-23 17:18:23:038619: starting main loop
# 2020-04-23 17:19:06:129442: end simulation loop
# 2020-04-23 17:19:06:129533: order analytics
# 2020-04-23 17:19:06:131985: VWAP run complete.
# percentage of aggressive order: 0.02967927237912877
# last_min_order: 109959.0
# avg price: 289.18032323333335
# day_vwap price: 287.75255930110154
# avg - day_vwap: 1.4277639322318123
# 2020-04-23 17:19:06:143937: 20190124 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:19:06:144022: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1345
# 2020-04-23 17:19:06:150079: starting main loop
# 2020-04-23 17:19:48:030516: end simulation loop
# 2020-04-23 17:19:48:030628: order analytics
# 2020-04-23 17:19:48:033465: VWAP run complete.
# percentage of aggressive order: 0.0172173103769195
# last_min_order: 120997.0
# avg price: 295.4699530333333
# day_vwap price: 294.2529570043719
# avg - day_vwap: 1.2169960289613755
# 2020-04-23 17:19:48:042371: 20190125 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:19:48:042453: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1460
# 2020-04-23 17:19:48:048304: starting main loop
# 2020-04-23 17:20:31:333187: end simulation loop
# 2020-04-23 17:20:31:333282: order analytics
# 2020-04-23 17:20:31:335822: VWAP run complete.
# percentage of aggressive order: 0.03543307086614173
# last_min_order: 107907.0
# avg price: 294.35370083333333
# day_vwap price: 293.3454132785871
# avg - day_vwap: 1.0082875547462322
# 2020-04-23 17:20:31:342823: 20190128 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:20:31:342886: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1450
# 2020-04-23 17:20:31:347772: starting main loop
# 2020-04-23 17:20:59:213549: end simulation loop
# 2020-04-23 17:20:59:213637: order analytics
# 2020-04-23 17:20:59:216002: VWAP run complete.
# percentage of aggressive order: 0.03553008595988539
# last_min_order: 101682.0
# avg price: 296.1169969333333
# day_vwap price: 295.61633583089167
# avg - day_vwap: 0.5006611024416543
# 2020-04-23 17:20:59:221422: 20190129 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:20:59:221496: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0946
# 2020-04-23 17:20:59:229074: starting main loop
# 2020-04-23 17:22:14:323775: end simulation loop
# 2020-04-23 17:22:14:323903: order analytics
# 2020-04-23 17:22:14:326430: VWAP run complete.
# percentage of aggressive order: 0.01834862385321101
# last_min_order: 142702.0
# avg price: 305.59016449999996
# day_vwap price: 303.60644835608593
# avg - day_vwap: 1.9837161439140232
# 2020-04-23 17:22:14:344690: 20190130 finished
# -------------------------------------------------------------------------------------------------
# ----------------Random_Forest-----------------
# 2020-04-23 17:22:14:344759: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1613
# 2020-04-23 17:22:14:352036: starting main loop
# 2020-04-23 17:23:29:816120: end simulation loop
# 2020-04-23 17:23:29:816216: order analytics
# 2020-04-23 17:23:29:818883: VWAP run complete.
# percentage of aggressive order: 0.040606060606060604
# last_min_order: 115645.0
# avg price: 305.71271199999995
# day_vwap price: 304.9707644846737
# avg - day_vwap: 0.7419475153262738
# 2020-04-23 17:23:29:835087: 20190131 finished

# %% [markdown]
# ## Gradient Boost

# %%
with open("model/GradientBoost_{}_{}.p".format(train_date_list[0],train_date_list[-1]),"rb") as f:
        model=pickle.load(f)
vwap_list, avg_list_GB, avg_spread_GB, _ = model_vwap_evaluation(model, 's')
# Out:
# 2020-04-23 17:23:32:067830: 20190117 finished
# 2020-04-23 17:23:46:729107: 20190118 finished
# 2020-04-23 17:23:52:773416: 20190122 finished
# 2020-04-23 17:23:59:093597: 20190123 finished
# 2020-04-23 17:24:02:721856: 20190124 finished
# 2020-04-23 17:24:06:007322: 20190125 finished
# 2020-04-23 17:24:08:906743: 20190128 finished
# 2020-04-23 17:24:10:970497: 20190129 finished
# 2020-04-23 17:24:16:749788: 20190130 finished
# 2020-04-23 17:24:23:768167: 20190131 finished
# 2020-04-23 17:24:23:857331: start merge
# 2020-04-23 17:24:23:881009: end merge
# 2020-04-23 17:24:23:881114: 20190117 finished
# 2020-04-23 17:24:24:383450: start merge
# 2020-04-23 17:24:24:547715: end merge
# 2020-04-23 17:24:24:547827: 20190118 finished
# 2020-04-23 17:24:24:725072: start merge
# 2020-04-23 17:24:24:771478: end merge
# 2020-04-23 17:24:24:771578: 20190124 finished
# 2020-04-23 17:24:24:920195: start merge
# 2020-04-23 17:24:24:963612: end merge
# 2020-04-23 17:24:24:963748: 20190125 finished
# 2020-04-23 17:24:25:116364: start merge
# 2020-04-23 17:24:25:157696: end merge
# 2020-04-23 17:24:25:157886: 20190128 finished
# 2020-04-23 17:24:25:276604: start merge
# 2020-04-23 17:24:25:308170: end merge
# 2020-04-23 17:24:25:308271: 20190129 finished
# 2020-04-23 17:24:25:567155: start merge
# 2020-04-23 17:24:25:639010: end merge
# 2020-04-23 17:24:25:639117: 20190130 finished
# 2020-04-23 17:24:25:919267: start merge
# 2020-04-23 17:24:25:989311: end merge
# 2020-04-23 17:24:25:989418: 20190131 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:24:25:989486: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1776
# 2020-04-23 17:24:25:995216: starting main loop
# 2020-04-23 17:24:56:612513: end simulation loop
# 2020-04-23 17:24:56:612612: order analytics
# 2020-04-23 17:24:56:615602: VWAP run complete.
# percentage of aggressive order: 0.040897097625329816
# last_min_order: 88585.0
# avg price: 347.28309613333334
# day_vwap price: 347.7609699903627
# avg - day_vwap: -0.47787385702935126
# 2020-04-23 17:24:56:620617: 20190117 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:24:56:620695: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0542
# 2020-04-23 17:24:56:634588: starting main loop
# 2020-04-23 17:27:37:950922: end simulation loop
# 2020-04-23 17:27:37:951022: order analytics
# 2020-04-23 17:27:37:953785: VWAP run complete.
# percentage of aggressive order: 0.02336448598130841
# last_min_order: 101440.0
# avg price: 308.84956099999994
# day_vwap price: 310.79745669649475
# avg - day_vwap: -1.947895696494811
# 2020-04-23 17:27:37:988987: 20190118 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:27:37:989060: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1385
# 2020-04-23 17:27:37:995197: starting main loop
# 2020-04-23 17:28:18:869719: end simulation loop
# 2020-04-23 17:28:18:869808: order analytics
# 2020-04-23 17:28:18:872741: VWAP run complete.
# percentage of aggressive order: 0.017002237136465325
# last_min_order: 125516.0
# avg price: 289.4194981666667
# day_vwap price: 287.75255930110154
# avg - day_vwap: 1.6669388655651574
# 2020-04-23 17:28:18:884403: 20190124 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:28:18:884510: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1345
# 2020-04-23 17:28:18:889819: starting main loop
# 2020-04-23 17:28:55:679282: end simulation loop
# 2020-04-23 17:28:55:679392: order analytics
# 2020-04-23 17:28:55:681960: VWAP run complete.
# percentage of aggressive order: 0.010805943268797838
# last_min_order: 126593.0
# avg price: 295.5251523
# day_vwap price: 294.2529570043719
# avg - day_vwap: 1.2721952956280802
# 2020-04-23 17:28:55:689995: 20190125 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:28:55:690057: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1460
# 2020-04-23 17:28:55:694900: starting main loop
# 2020-04-23 17:29:28:849658: end simulation loop
# 2020-04-23 17:29:28:849746: order analytics
# 2020-04-23 17:29:28:852026: VWAP run complete.
# percentage of aggressive order: 0.021063717746182202
# last_min_order: 116408.0
# avg price: 294.39919100000003
# day_vwap price: 293.3454132785871
# avg - day_vwap: 1.0537777214129278
# 2020-04-23 17:29:28:859334: 20190128 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:29:28:859401: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1450
# 2020-04-23 17:29:28:863816: starting main loop
# 2020-04-23 17:30:00:969265: end simulation loop
# 2020-04-23 17:30:00:969354: order analytics
# 2020-04-23 17:30:00:971685: VWAP run complete.
# percentage of aggressive order: 0.02203116603976357
# last_min_order: 111400.0
# avg price: 296.16124179999997
# day_vwap price: 295.61633583089167
# avg - day_vwap: 0.5449059691082994
# 2020-04-23 17:30:00:976621: 20190129 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:30:00:976674: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0946
# 2020-04-23 17:30:00:983709: starting main loop
# 2020-04-23 17:31:05:486033: end simulation loop
# 2020-04-23 17:31:05:486122: order analytics
# 2020-04-23 17:31:05:488489: VWAP run complete.
# percentage of aggressive order: 0.012552301255230125
# last_min_order: 147641.0
# avg price: 305.6674475666667
# day_vwap price: 303.60644835608593
# avg - day_vwap: 2.0609992105807464
# 2020-04-23 17:31:05:505895: 20190130 finished
# -------------------------------------------------------------------------------------------------
# ----------------GradientBoost-----------------
# 2020-04-23 17:31:05:505966: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1613
# 2020-04-23 17:31:05:512439: starting main loop
# 2020-04-23 17:32:02:045018: end simulation loop
# 2020-04-23 17:32:02:045104: order analytics
# 2020-04-23 17:32:02:047467: VWAP run complete.
# percentage of aggressive order: 0.025551684088269456
# last_min_order: 127447.0
# avg price: 305.8216635
# day_vwap price: 304.9707644846737
# avg - day_vwap: 0.8508990153263198
# 2020-04-23 17:32:02:062306: 20190131 finished

# %% [markdown]
# ## XGBoost

# %%
with open("model/XGBoost_{}_{}.p".format(train_date_list[0],train_date_list[-1]),"rb") as f:
        model=pickle.load(f)
vwap_list, avg_list_XGB, avg_spread_XGB, _ = model_vwap_evaluation(model, 's')
# Out:
# 2020-04-23 17:32:03:076928: 20190117 finished
# 2020-04-23 17:32:09:106194: 20190118 finished
# 2020-04-23 17:32:12:150320: 20190122 finished
# 2020-04-23 17:32:15:723603: 20190123 finished
# 2020-04-23 17:32:17:903908: 20190124 finished
# 2020-04-23 17:32:19:847694: 20190125 finished
# 2020-04-23 17:32:21:476649: 20190128 finished
# 2020-04-23 17:32:22:725109: 20190129 finished
# 2020-04-23 17:32:26:051828: 20190130 finished
# 2020-04-23 17:32:29:997530: 20190131 finished
# 2020-04-23 17:32:30:160937: start merge
# 2020-04-23 17:32:30:188986: end merge
# 2020-04-23 17:32:30:189098: 20190117 finished
# 2020-04-23 17:32:30:816741: start merge
# 2020-04-23 17:32:31:013673: end merge
# 2020-04-23 17:32:31:013818: 20190118 finished
# 2020-04-23 17:32:31:232495: start merge
# 2020-04-23 17:32:31:288962: end merge
# 2020-04-23 17:32:31:289092: 20190124 finished
# 2020-04-23 17:32:31:478507: start merge
# 2020-04-23 17:32:31:529929: end merge
# 2020-04-23 17:32:31:530042: 20190125 finished
# 2020-04-23 17:32:31:694651: start merge
# 2020-04-23 17:32:31:741092: end merge
# 2020-04-23 17:32:31:741209: 20190128 finished
# 2020-04-23 17:32:31:880855: start merge
# 2020-04-23 17:32:31:915674: end merge
# 2020-04-23 17:32:31:915790: 20190129 finished
# 2020-04-23 17:32:32:218403: start merge
# 2020-04-23 17:32:32:304267: end merge
# 2020-04-23 17:32:32:304419: 20190130 finished
# 2020-04-23 17:32:32:607635: start merge
# 2020-04-23 17:32:32:684351: end merge
# 2020-04-23 17:32:32:684475: 20190131 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:32:32:684559: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1776
# 2020-04-23 17:32:32:690366: starting main loop
# 2020-04-23 17:32:54:128441: end simulation loop
# 2020-04-23 17:32:54:128532: order analytics
# 2020-04-23 17:32:54:130928: VWAP run complete.
# percentage of aggressive order: 0.03861003861003861
# last_min_order: 88606.0
# avg price: 347.2900998
# day_vwap price: 347.7609699903627
# avg - day_vwap: -0.47087019036268885
# 2020-04-23 17:32:54:134759: 20190117 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:32:54:134815: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0542
# 2020-04-23 17:32:54:145902: starting main loop
# 2020-04-23 17:35:30:787373: end simulation loop
# 2020-04-23 17:35:30:787497: order analytics
# 2020-04-23 17:35:30:790202: VWAP run complete.
# percentage of aggressive order: 0.02384393063583815
# last_min_order: 101655.0
# avg price: 308.8262665666667
# day_vwap price: 310.79745669649475
# avg - day_vwap: -1.9711901298280736
# 2020-04-23 17:35:30:823967: 20190118 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:35:30:824039: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1385
# 2020-04-23 17:35:30:830168: starting main loop
# 2020-04-23 17:36:13:433982: end simulation loop
# 2020-04-23 17:36:13:434079: order analytics
# 2020-04-23 17:36:13:436503: VWAP run complete.
# percentage of aggressive order: 0.01651048639000446
# last_min_order: 125767.0
# avg price: 289.4293118
# day_vwap price: 287.75255930110154
# avg - day_vwap: 1.676752498898452
# 2020-04-23 17:36:13:445623: 20190124 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:36:13:445682: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1345
# 2020-04-23 17:36:13:450844: starting main loop
# 2020-04-23 17:36:49:135481: end simulation loop
# 2020-04-23 17:36:49:135599: order analytics
# 2020-04-23 17:36:49:138444: VWAP run complete.
# percentage of aggressive order: 0.010752688172043012
# last_min_order: 128137.0
# avg price: 295.55584816666664
# day_vwap price: 294.2529570043719
# avg - day_vwap: 1.3028911622947135
# 2020-04-23 17:36:49:146597: 20190125 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:36:49:146661: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1460
# 2020-04-23 17:36:49:152373: starting main loop
# 2020-04-23 17:37:23:205209: end simulation loop
# 2020-04-23 17:37:23:205304: order analytics
# 2020-04-23 17:37:23:207910: VWAP run complete.
# percentage of aggressive order: 0.02168164992067689
# last_min_order: 115966.0
# avg price: 294.4042891333333
# day_vwap price: 293.3454132785871
# avg - day_vwap: 1.0588758547461907
# 2020-04-23 17:37:23:215296: 20190128 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:37:23:215369: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1450
# 2020-04-23 17:37:23:220170: starting main loop
# 2020-04-23 17:37:53:228505: end simulation loop
# 2020-04-23 17:37:53:228598: order analytics
# 2020-04-23 17:37:53:231064: VWAP run complete.
# percentage of aggressive order: 0.02088912694161757
# last_min_order: 113299.0
# avg price: 296.16923226666665
# day_vwap price: 295.61633583089167
# avg - day_vwap: 0.5528964357749828
# 2020-04-23 17:37:53:236714: 20190129 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:37:53:236780: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0946
# 2020-04-23 17:37:53:245201: starting main loop
# 2020-04-23 17:39:04:170187: end simulation loop
# 2020-04-23 17:39:04:170279: order analytics
# 2020-04-23 17:39:04:172599: VWAP run complete.
# percentage of aggressive order: 0.012035583464154892
# last_min_order: 147897.0
# avg price: 305.67446363333335
# day_vwap price: 303.60644835608593
# avg - day_vwap: 2.0680152772474116
# 2020-04-23 17:39:04:189471: 20190130 finished
# -------------------------------------------------------------------------------------------------
# ----------------XGBoost-----------------
# 2020-04-23 17:39:04:189538: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1613
# 2020-04-23 17:39:04:195948: starting main loop
# 2020-04-23 17:40:04:180535: end simulation loop
# 2020-04-23 17:40:04:180636: order analytics
# 2020-04-23 17:40:04:183159: VWAP run complete.
# percentage of aggressive order: 0.02619324796274738
# last_min_order: 125662.0
# avg price: 305.7763020666667
# day_vwap price: 304.9707644846737
# avg - day_vwap: 0.8055375819930077
# 2020-04-23 17:40:04:198190: 20190131 finished

# %% [markdown]
# ## Tick Factor

# %%
test_taq=dict()

for date in test_date_list:
    if os.path.exists("test_result/x_test_{}.p".format(date)) and os.path.exists(data_dir+"quotes_{}_TSLA.csv".format(date)):
        
        trades = pd.read_csv(data_dir+'trades_{}_{}.csv'.format(date, ticker),index_col=[0],parse_dates=[0])
        
        
        # merge TAQ
        quotes=pd.read_csv(data_dir+"quotes_{}_TSLA.csv".format(date),index_col=[0],parse_dates=[0])
        taq=makeTAQfile(trades, quotes)
        print(taq.shape)
        test_taq[date]=taq
        
        log_message( "{} finished".format(date) )
# Out:
# 2020-04-23 17:58:58:863641: start merge
# 2020-04-23 17:58:58:882777: end merge
# (50301, 9)
# 2020-04-23 17:58:58:882875: 20190117 finished
# 2020-04-23 17:58:59:323360: start merge
# 2020-04-23 17:58:59:459393: end merge
# (428445, 9)
# 2020-04-23 17:58:59:459525: 20190118 finished
# 2020-04-23 17:58:59:610558: start merge
# 2020-04-23 17:58:59:649588: end merge
# (113260, 9)
# 2020-04-23 17:58:59:649693: 20190124 finished
# 2020-04-23 17:58:59:782483: start merge
# 2020-04-23 17:58:59:818529: end merge
# (99211, 9)
# 2020-04-23 17:58:59:818672: 20190125 finished
# 2020-04-23 17:58:59:931235: start merge
# 2020-04-23 17:58:59:964147: end merge
# (89710, 9)
# 2020-04-23 17:58:59:964248: 20190128 finished
# 2020-04-23 17:59:00:064629: start merge
# 2020-04-23 17:59:00:089848: end merge
# (66041, 9)
# 2020-04-23 17:59:00:089967: 20190129 finished
# 2020-04-23 17:59:00:299195: start merge
# 2020-04-23 17:59:00:358964: end merge
# (202140, 9)
# 2020-04-23 17:59:00:359078: 20190130 finished
# 2020-04-23 17:59:00:589182: start merge
# 2020-04-23 17:59:00:647747: end merge
# (174960, 9)
# 2020-04-23 17:59:00:647859: 20190131 finished

# %%
avg_list_tick=[]

model_coef=0.1

for date in test_taq.keys():
    print("-------------------------------------------------------------------------------------------------")
    day=test_taq[date]
    print("----------------Tick-----------------")
    r_tick=test_vwap(day, order_quantity=300000, order_side="s", schedule_coef = -1.0, tick_coef = 1., model_coef = 0.,model=False)

    avg_list_tick.append(r_tick['avg_price'])

    log_message( "{} finished".format(date) )
# Out:
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:00:25:994133: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1776
# 2020-04-23 18:00:25:999440: starting main loop
# 2020-04-23 18:00:46:097925: end simulation loop
# 2020-04-23 18:00:46:098016: order analytics
# 2020-04-23 18:00:46:100986: VWAP run complete.
# percentage of aggressive order: 0.11376292760540971
# last_min_order: 65901.0
# avg price: 347.31255029999994
# day_vwap price: 347.7609699903627
# avg - day_vwap: -0.44841969036275486
# 2020-04-23 18:00:46:104191: 20190117 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:00:46:104247: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0542
# 2020-04-23 18:00:46:119684: starting main loop
# 2020-04-23 18:02:51:001987: end simulation loop
# 2020-04-23 18:02:51:002083: order analytics
# 2020-04-23 18:02:51:004751: VWAP run complete.
# percentage of aggressive order: 0.04912708079577751
# last_min_order: 87304.0
# avg price: 309.25981913333334
# day_vwap price: 310.79745669649475
# avg - day_vwap: -1.537637563161411
# 2020-04-23 18:02:51:037750: 20190118 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:02:51:037822: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1385
# 2020-04-23 18:02:51:044547: starting main loop
# 2020-04-23 18:03:28:417738: end simulation loop
# 2020-04-23 18:03:28:417828: order analytics
# 2020-04-23 18:03:28:420158: VWAP run complete.
# percentage of aggressive order: 0.05937992643194955
# last_min_order: 98356.0
# avg price: 289.0224237
# day_vwap price: 287.75255930110154
# avg - day_vwap: 1.2698643988984486
# 2020-04-23 18:03:28:428507: 20190124 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:03:28:428573: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1345
# 2020-04-23 18:03:28:434080: starting main loop
# 2020-04-23 18:04:05:438422: end simulation loop
# 2020-04-23 18:04:05:438511: order analytics
# 2020-04-23 18:04:05:440859: VWAP run complete.
# percentage of aggressive order: 0.06199460916442048
# last_min_order: 93610.0
# avg price: 295.2240061333333
# day_vwap price: 294.2529570043719
# avg - day_vwap: 0.971049128961397
# 2020-04-23 18:04:05:448167: 20190125 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:04:05:448235: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1460
# 2020-04-23 18:04:05:452695: starting main loop
# 2020-04-23 18:04:37:529647: end simulation loop
# 2020-04-23 18:04:37:529750: order analytics
# 2020-04-23 18:04:37:532326: VWAP run complete.
# percentage of aggressive order: 0.0859375
# last_min_order: 84872.0
# avg price: 294.16202633333336
# day_vwap price: 293.3454132785871
# avg - day_vwap: 0.8166130547462558
# 2020-04-23 18:04:37:539242: 20190128 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:04:37:539322: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1450
# 2020-04-23 18:04:37:543938: starting main loop
# 2020-04-23 18:05:05:083772: end simulation loop
# 2020-04-23 18:05:05:083866: order analytics
# 2020-04-23 18:05:05:086382: VWAP run complete.
# percentage of aggressive order: 0.08178191489361702
# last_min_order: 79273.0
# avg price: 296.0066152333333
# day_vwap price: 295.61633583089167
# avg - day_vwap: 0.3902794024416494
# 2020-04-23 18:05:05:091073: 20190129 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:05:05:091133: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.0946
# 2020-04-23 18:05:05:098340: starting main loop
# 2020-04-23 18:06:16:561090: end simulation loop
# 2020-04-23 18:06:16:561196: order analytics
# 2020-04-23 18:06:16:563972: VWAP run complete.
# percentage of aggressive order: 0.06303549571603427
# last_min_order: 115890.0
# avg price: 305.049798
# day_vwap price: 303.60644835608593
# avg - day_vwap: 1.4433496439140754
# 2020-04-23 18:06:16:583478: 20190130 finished
# -------------------------------------------------------------------------------------------------
# ----------------Tick-----------------
# 2020-04-23 18:06:16:583561: Beginning VWAP run: s 300000 shares
# Average stock spread for sample: 0.1613
# 2020-04-23 18:06:16:592544: starting main loop
# 2020-04-23 18:07:28:057645: end simulation loop
# 2020-04-23 18:07:28:057740: order analytics
# 2020-04-23 18:07:28:060346: VWAP run complete.
# percentage of aggressive order: 0.1026536312849162
# last_min_order: 82922.0
# avg price: 305.45605439999997
# day_vwap price: 304.9707644846737
# avg - day_vwap: 0.48528991532629107
# 2020-04-23 18:07:28:074089: 20190131 finished

# %% [markdown]
# # Comparison of Models

# %%
len(avg_list_tick), len(avg_list_LSTM)

# %%
df_compare=pd.DataFrame({"Tick factor":avg_list_tick,
                         "LSTM factor":avg_list_LSTM,
                         "CNN factor":avg_list_CNN,
                         "RandomForest factor":avg_list_RF,
                         "GradientBoost factor":avg_list_GB,
                         "XGBoost factor":avg_list_XGB,
                        },
                        index=pd.to_datetime(list(test_taq.keys())))
df_compare["Avg LSTM - Avg factor"]=df_compare["LSTM factor"]-df_compare["Tick factor"]
df_compare["Avg CNN - Avg factor"]=df_compare["CNN factor"]-df_compare["Tick factor"]
df_compare["Avg RandomForest - Avg factor"]=df_compare["RandomForest factor"]-df_compare["Tick factor"]
df_compare["Avg GradientBoost - Avg factor"]=df_compare["GradientBoost factor"]-df_compare["Tick factor"]
df_compare["Avg XGBoost - Avg factor"]=df_compare["XGBoost factor"]-df_compare["Tick factor"]
fig,ax=plt.subplots(figsize=(16,6))
ax.plot(df_compare.index,df_compare["Avg LSTM - Avg factor"].values,'o--')
ax.plot(df_compare.index,df_compare["Avg CNN - Avg factor"].values,'o--')
ax.plot(df_compare.index,df_compare["Avg RandomForest - Avg factor"].values,'o--')
ax.plot(df_compare.index,df_compare["Avg GradientBoost - Avg factor"].values,'o--')
ax.plot(df_compare.index,df_compare["Avg XGBoost - Avg factor"].values,'o--')
plt.legend(["LSTM", "CNN", "RF", "GB", "XGB"])
